# %%
import tensorflow
from keras.optimizers import Adam, SGD
from keras.callbacks import ModelCheckpoint, LearningRateScheduler, TerminateOnNaN, CSVLogger
from keras import backend as K
from keras.models import load_model
from math import ceil
import numpy as np
from matplotlib import pyplot as plt
import time
from models.keras_ssd300 import ssd_300
from models.keras_ssd512 import ssd_512
from keras_loss_function.keras_ssd_loss import SSDLoss
from keras_layers.keras_layer_AnchorBoxes import AnchorBoxes
from keras_layers.keras_layer_DecodeDetections import DecodeDetections
from keras_layers.keras_layer_DecodeDetectionsFast import DecodeDetectionsFast
from keras_layers.keras_layer_L2Normalization import L2Normalization

from ssd_encoder_decoder.ssd_input_encoder import SSDInputEncoder
from ssd_encoder_decoder.ssd_output_decoder import decode_detections, decode_detections_fast

# from data_generator.object_detection_2d_data_generator import DataGenerator
# from data_generator.object_detection_2d_geometric_ops import Resize
# from data_generator.object_detection_2d_photometric_ops import ConvertTo3Channels
# from data_generator.data_augmentation_chain_original_ssd import SSDDataAugmentation
# from data_generator.object_detection_2d_misc_utils import apply_inverse_transforms
from bs4 import BeautifulSoup
import lxml
import et_xmlfile
from et_xmlfile import xmlfile
import requests
import argparse
import os
import math
import cv2
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # EXTRACT FRAMES FROM VIDEO WITH OBJECT DETECTION

# %%
img_height = 300 # Height of the model input images
img_width = 300 # Width of the model input images
img_channels = 3 # Number of color channels of the model input images
mean_color = [123, 117, 104] # The per-channel mean of the images in the dataset. Do not change this value if you're using any of the pre-trained weights.
swap_channels = [2, 1, 0] # The color channel order in the original SSD is BGR, so we'll have the model reverse the color channel order of the input images.
n_classes = 20 # Number of positive classes, e.g. 20 for Pascal VOC, 80 for MS COCO
scales_pascal = [0.1, 0.2, 0.37, 0.54, 0.71, 0.88, 1.05] # The anchor box scaling factors used in the original SSD300 for the Pascal VOC datasets
scales_coco = [0.07, 0.15, 0.33, 0.51, 0.69, 0.87, 1.05] # The anchor box scaling factors used in the original SSD300 for the MS COCO datasets
scales = scales_pascal
aspect_ratios = [[1.0, 2.0, 0.5],
                 [1.0, 2.0, 0.5, 3.0, 1.0/3.0],
                 [1.0, 2.0, 0.5, 3.0, 1.0/3.0],
                 [1.0, 2.0, 0.5, 3.0, 1.0/3.0],
                 [1.0, 2.0, 0.5],
                 [1.0, 2.0, 0.5]] # The anchor box aspect ratios used in the original SSD300; the order matters
two_boxes_for_ar1 = True
steps = [8, 16, 32, 64, 100, 300] # The space between two adjacent anchor box center points for each predictor layer.
offsets = [0.5, 0.5, 0.5, 0.5, 0.5, 0.5] # The offsets of the first anchor box center points from the top and left borders of the image as a fraction of the step size for each predictor layer.
clip_boxes = False # Whether or not to clip the anchor boxes to lie entirely within the image boundaries
variances = [0.1, 0.1, 0.2, 0.2] # The variances by which the encoded target coordinates are divided as in the original implementation
normalize_coords = True

# %%
# 1: Build the Keras model.

K.clear_session() # Clear previous models from memory.

model = ssd_300(image_size=(img_height, img_width, img_channels),
                n_classes=n_classes,
                mode='training',
                l2_regularization=0.0005,
                scales=scales,
                aspect_ratios_per_layer=aspect_ratios,
                two_boxes_for_ar1=two_boxes_for_ar1,
                steps=steps,
                offsets=offsets,
                clip_boxes=clip_boxes,
                variances=variances,
                normalize_coords=normalize_coords,
                subtract_mean=mean_color,
                swap_channels=swap_channels)

# 2: Load some weights into the model.

# TODO: Set the path to the weights you want to load.
weights_path ='utils/checkpoints/object/VGG_VOC0712Plus_SSD_300x300_ft_iter_160000.h5'


model.load_weights(weights_path, by_name=True)

# 3: Instantiate an optimizer and the SSD loss function and compile the model.
#    If you want to follow the original Caffe implementation, use the preset SGD
#    optimizer, otherwise I'd recommend the commented-out Adam optimizer.
sgd = SGD(lr=0.001, momentum=0.9, decay=0.0, nesterov=False)

ssd_loss = SSDLoss(neg_pos_ratio=3, alpha=1.0)

model.compile(optimizer=sgd, loss=ssd_loss.compute_loss,metrics=['accuracy'])

#model.compile(optimizer=sgd, loss=[focal_loss(alpha=0.25, gamma=2)],metrics=['accuracy'])
# Out:
# WARNING:tensorflow:From E:\Anaconda\envs\tf_gpu\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From G:\Project_Theo\Project\keras_loss_function\keras_ssd_loss.py:133: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# WARNING:tensorflow:From G:\Project_Theo\Project\keras_loss_function\keras_ssd_loss.py:166: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.

# %% [markdown]
# # AUTOMATICALLY EXTRACT RANDOM GLOBAL + LOCAL  FRAME WHENEVER OBJECT IS DETECTED

# %%
classes = ['background',
           'aeroplane', 'bicycle', 'bird', 'boat',
           'bottle', 'bus', 'car', 'cat',
           'chair', 'cow', 'diningtable', 'dog',
           'horse', 'motorbike', 'person', 'pottedplant',
           'sheep', 'sofa', 'train', 'tvmonitor']

np.set_printoptions(precision=2, suppress=True, linewidth=90)
data_path = 'edited_videos'
import random
ctg = os.listdir(data_path)
#ctg = ['happy','sad','submissive']
file_dir = os.path.join(os.getcwd(),data_path)
for x in ctg:
    count_file = 1
    listing = os.listdir(os.path.join(data_path,x))
    for file in listing:
        count_clip = 1
        count_image = 0
        vid_dir = os.path.join(file_dir,x,file)
        video = cv2.VideoCapture(vid_dir)
        print(video.isOpened())
        framerate = video.get(5)
        totalframe = int(video.get(7))    
        if(totalframe > 500):
            randlist = []
            rand = random.sample(range(1,totalframe-500),1)[0]        
            for i in range(rand, rand+500):
                randlist.append(i)
        else:
            randlist = range(0, (totalframe-(totalframe%25)+1))
        print(count_file)
        if(count_file <= 20):
            gen = 'train'
        elif(count_file >= 21 and count_file < 26):
            gen = 'val'
        elif(count_file >=26 and count_file <31):
            gen = 'test'
        else:
            gen = 'deposit'
        new_path = os.path.join(os.getcwd(),'data',gen,x,"video_" + str("{:02d}".format(count_file)))
        object_path = os.path.join(os.getcwd(),'object_data',gen,x,"video_" + str("{:02d}".format(count_file))) 
        OF_path = os.path.join(os.getcwd(),'OF_data',gen,x,"video_" + str("{:02d}".format(count_file)))
        ret, frame1 = video.read()
        prvs = cv2.cvtColor(frame1,cv2.COLOR_BGR2GRAY)
        hsv = np.zeros_like(frame1)
        hsv[...,1] = 25
        while (video.isOpened()):
            start = time.time()
            success,image = video.read()
            if (success != True):
                break
            frameId = video.get(1)
            if(frameId in randlist):
                program_starts = time.time()
                clip_path = os.path.join(new_path+'_clip_'+str("{:02d}".format(count_clip)))
                filename = os.path.join(clip_path,"image_"+str("{:05d}".format(count_image))+'.jpg')  

                objclip_path = os.path.join(object_path+'_clip_'+str("{:02d}".format(count_clip)))
                obj_filename = os.path.join(objclip_path,"image_"+str("{:05d}".format(count_image))+'.jpg')

                OFclip_path = os.path.join(OF_path+'_clip_'+str("{:02d}".format(count_clip)))
                OFfilename = os.path.join(OFclip_path,"image_"+str("{:05d}".format(count_image))+'.jpg')  
            
                if not os.path.exists(clip_path):
                    os.makedirs(clip_path)   
                if not os.path.exists(objclip_path):
                    os.makedirs(objclip_path)  
                if not os.path.exists(OFclip_path):
                    os.makedirs(OFclip_path)   
                img_resized = cv2.resize(image,(img_width,img_height))
                img_reshape=img_resized.reshape(1,img_width,img_height,3)
                y_pred = model.predict(img_reshape)
                y_pred_decoded = decode_detections(y_pred,
                                                   confidence_thresh=0.2,
                                                   iou_threshold=0.4,
                                                   top_k=200,
                                                   normalize_coords=normalize_coords,
                                                   img_height=img_height,
                                                   img_width=img_width)
                countdog = 1
                next = cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
                flow = cv2.calcOpticalFlowFarneback(prvs,next, None, 0.5, 3, 15, 3, 5, 1.2, 0)
                mag, ang = cv2.cartToPolar(flow[...,0], flow[...,1])
                hsv[...,0] = ang*180/np.pi/2
                hsv[...,2] = cv2.normalize(mag,None,0,255,cv2.NORM_MINMAX)
                bgr = cv2.cvtColor(hsv,cv2.COLOR_HSV2BGR)
                for i in range(len(y_pred_decoded[0])):
                    pred = y_pred_decoded[0][i][0]
                    conf = y_pred_decoded[0][i][1]
                    if(pred == 12 and conf > 0.3 and countdog == 1): #CLASS = DOG
                        #class   conf xmin   ymin   xmax   ymax
                        #print(pred,conf)
                        xmin = max(0,y_pred_decoded[0][i][2] * 1280 / 300) #xmin
                        ymin = max(0,y_pred_decoded[0][i][3]  * 720 / 300) #ymin
                        xmax = max(0,y_pred_decoded[0][i][4] * 1280 / 300) #xmax
                        ymax = max(0,y_pred_decoded[0][i][5]  * 720 / 300) #ymax
                        newimg = image[int(ymin):int(ymax), int(xmin):int(xmax), :]
                        bgr = cv2.resize(bgr,(640,480))
                        image = cv2.resize(image,(640,480))
                        cv2.imwrite(str(filename),image)
                        cv2.imwrite(str(obj_filename),newimg)     
                        cv2.imwrite(str(OFfilename),bgr) 
                        countdog += 1
                        count_image +=1
                prvs = next
                if(count_image % 50 == 0 and count_image > 0):
                    count_clip+=1  
                stop = time.time()
                duration = stop-start
                print("file:",filename, 'duration:', duration, end = '\r')
        video.release()
        count_file += 1
# Out:
# True
# 1
# True: G:\Project_Theo\Project\data\train\angry\video_01_clip_04\image_00197.jpg duration: 0.27106332778930664
# 2
# True: G:\Project_Theo\Project\data\train\angry\video_02_clip_03\image_00129.jpg duration: 0.26005721092224124
# 3
# True: G:\Project_Theo\Project\data\train\angry\video_03_clip_10\image_00417.jpg duration: 0.27106046676635743
# 4
# True: G:\Project_Theo\Project\data\train\angry\video_04_clip_10\image_00473.jpg duration: 0.27606248855590825
# 5
# True: G:\Project_Theo\Project\data\train\angry\video_05_clip_09\image_00434.jpg duration: 0.30706882476806646
# 6
# True: G:\Project_Theo\Project\data\train\angry\video_06_clip_05\image_00237.jpg duration: 0.30306863784790046
# 7
# True: G:\Project_Theo\Project\data\train\angry\video_07_clip_05\image_00238.jpg duration: 0.26906061172485355
# 8
# True: G:\Project_Theo\Project\data\train\angry\video_08_clip_07\image_00346.jpg duration: 0.27706313133239746
# 9
# True: G:\Project_Theo\Project\data\train\angry\video_09_clip_09\image_00258.jpg duration: 0.27806234359741217
# 10
# True: G:\Project_Theo\Project\data\train\angry\video_10_clip_05\image_00248.jpg duration: 0.30006694793701176
# 11
# True: G:\Project_Theo\Project\data\train\angry\video_11_clip_09\image_00410.jpg duration: 0.29106521606445314
# 12
# True: G:\Project_Theo\Project\data\train\angry\video_12_clip_12\image_00226.jpg duration: 0.27706170082092285
# 13
# True: G:\Project_Theo\Project\data\train\angry\video_13_clip_10\image_00495.jpg duration: 0.28906488418579155
# 14
# True: G:\Project_Theo\Project\data\train\angry\video_14_clip_10\image_00479.jpg duration: 0.28806400299072266
# 15
# True: G:\Project_Theo\Project\data\train\angry\video_15_clip_10\image_00499.jpg duration: 0.30106735229492197
# 16
# True: G:\Project_Theo\Project\data\train\angry\video_16_clip_10\image_00499.jpg duration: 0.28506422042846685
# 17
# True: G:\Project_Theo\Project\data\train\angry\video_17_clip_10\image_00417.jpg duration: 0.28006291389465335
# 18
# True: G:\Project_Theo\Project\data\train\angry\video_18_clip_10\image_00499.jpg duration: 0.27706265449523926
# 19
# True: G:\Project_Theo\Project\data\train\angry\video_19_clip_09\image_00424.jpg duration: 0.28306317329406747
# 20
# True: G:\Project_Theo\Project\data\train\angry\video_20_clip_10\image_00492.jpg duration: 0.27806234359741217
# 21
# True: G:\Project_Theo\Project\data\val\angry\video_21_clip_10\image_00486.jpg duration: 0.29006528854370117
# 22
# True: G:\Project_Theo\Project\data\val\angry\video_22_clip_10\image_00457.jpg duration: 0.28506326675415046
# 23
# True: G:\Project_Theo\Project\data\val\angry\video_23_clip_12\image_00421.jpg duration: 0.29239368438720703
# 24
# True: G:\Project_Theo\Project\data\val\angry\video_24_clip_11\image_00322.jpg duration: 0.27700877189636233
# 25
# True: G:\Project_Theo\Project\data\val\angry\video_25_clip_04\image_00198.jpg duration: 0.26133704185485845
# 26
# True: G:\Project_Theo\Project\data\test\angry\video_26_clip_10\image_00499.jpg duration: 0.30859255790710456
# 27
# True: G:\Project_Theo\Project\data\test\angry\video_27_clip_10\image_00499.jpg duration: 0.30391240119934086
# 28
# True: G:\Project_Theo\Project\data\test\angry\video_28_clip_10\image_00496.jpg duration: 0.30431938171386725
# 29
# True: G:\Project_Theo\Project\data\test\angry\video_29_clip_10\image_00497.jpg duration: 0.30842304229736334
# 30
# True: G:\Project_Theo\Project\data\test\angry\video_30_clip_10\image_00486.jpg duration: 0.26564288139343264
# 31
# True: G:\Project_Theo\Project\data\deposit\angry\video_31_clip_11\image_00267.jpg duration: 0.28126788139343264
# 32
# True: G:\Project_Theo\Project\data\deposit\angry\video_32_clip_09\image_00435.jpg duration: 0.28126668930053714
# 33
# True: G:\Project_Theo\Project\data\deposit\angry\video_33_clip_09\image_00416.jpg duration: 0.28126835823059083
# 34
# True: G:\Project_Theo\Project\data\deposit\angry\video_34_clip_04\image_00170.jpg duration: 0.26564121246337893
# 35
# True: G:\Project_Theo\Project\data\deposit\angry\video_35_clip_09\image_00392.jpg duration: 0.26564455032348633
# 36
# True: G:\Project_Theo\Project\data\deposit\angry\video_36_clip_13\image_00315.jpg duration: 0.29689478874206543
# 37
# True: G:\Project_Theo\Project\data\deposit\angry\video_37_clip_01\image_00000.jpg duration: 0.25001621246337893
# 38
# True: G:\Project_Theo\Project\data\deposit\angry\video_38_clip_01\image_00000.jpg duration: 0.25001478195190433
# 39
# True: G:\Project_Theo\Project\data\deposit\angry\video_39_clip_08\image_00355.jpg duration: 0.28126764297485354
# 40
# True: G:\Project_Theo\Project\data\deposit\angry\video_40_clip_10\image_00496.jpg duration: 0.29689478874206543
# 1
# True: G:\Project_Theo\Project\data\train\happy\video_01_clip_05\image_00247.jpg duration: 0.29689574241638184
# 2
# True: G:\Project_Theo\Project\data\train\happy\video_02_clip_09\image_00411.jpg duration: 0.28127026557922363
# 3
# True: G:\Project_Theo\Project\data\train\happy\video_03_clip_06\image_00253.jpg duration: 0.28506374359130867
# 4
# True: G:\Project_Theo\Project\data\train\happy\video_04_clip_09\image_00414.jpg duration: 0.27806234359741215
# 5
# True: G:\Project_Theo\Project\data\train\happy\video_05_clip_05\image_00200.jpg duration: 0.27906250953674316
# 6
# True: G:\Project_Theo\Project\data\train\happy\video_06_clip_07\image_00337.jpg duration: 0.28106260299682617
# 7
# True: G:\Project_Theo\Project\data\train\happy\video_07_clip_09\image_00446.jpg duration: 0.29806709289550786
# 8
# True: G:\Project_Theo\Project\data\train\happy\video_08_clip_04\image_00177.jpg duration: 0.26305818557739265
# 9
# True: G:\Project_Theo\Project\data\train\happy\video_09_clip_09\image_00413.jpg duration: 0.27906227111816406
# 10
# True: G:\Project_Theo\Project\data\train\happy\video_10_clip_09\image_00442.jpg duration: 0.26305961608886725
# 11
# True: G:\Project_Theo\Project\data\train\happy\video_11_clip_84\image_00145.jpg duration: 0.27606463432312013
# 12
# True: G:\Project_Theo\Project\data\train\happy\video_12_clip_07\image_00308.jpg duration: 0.25605773925781256
# 13
# True: G:\Project_Theo\Project\data\train\happy\video_13_clip_01\image_00001.jpg duration: 0.26605916023254395
# 14
# True: G:\Project_Theo\Project\data\train\happy\video_14_clip_05\image_00245.jpg duration: 0.28206348419189453
# 15
# True: G:\Project_Theo\Project\data\train\happy\video_15_clip_10\image_00460.jpg duration: 0.27806258201599123
# 16
# True: G:\Project_Theo\Project\data\train\happy\video_16_clip_06\image_00186.jpg duration: 0.25105667114257814
# 17
# True: G:\Project_Theo\Project\data\train\happy\video_17_clip_06\image_00265.jpg duration: 0.28356742858886724
# 18
# True: G:\Project_Theo\Project\data\train\happy\video_18_clip_09\image_00416.jpg duration: 0.29606699943542487
# 19
# True: G:\Project_Theo\Project\data\train\happy\video_19_clip_10\image_00453.jpg duration: 0.26205873489379883
# 20
# True: G:\Project_Theo\Project\data\train\happy\video_20_clip_07\image_00254.jpg duration: 0.29333972930908203
# 21
# True: G:\Project_Theo\Project\data\val\happy\video_21_clip_05\image_00223.jpg duration: 0.30892682075500494
# 22
# True: G:\Project_Theo\Project\data\val\happy\video_22_clip_17\image_00440.jpg duration: 0.28606343269348145
# 23
# True: G:\Project_Theo\Project\data\val\happy\video_23_clip_02\image_00092.jpg duration: 0.28606462478637695
# 24
# True: G:\Project_Theo\Project\data\val\happy\video_24_clip_09\image_00431.jpg duration: 0.25705814361572266
# 25
# True: G:\Project_Theo\Project\data\val\happy\video_25_clip_10\image_00497.jpg duration: 0.28506469726562576
# 26
# True: G:\Project_Theo\Project\data\test\happy\video_26_clip_04\image_00175.jpg duration: 0.27407336235046387
# 27
# True: G:\Project_Theo\Project\data\test\happy\video_27_clip_01\image_00049.jpg duration: 0.26239252090454196
# 28
# True: G:\Project_Theo\Project\data\test\happy\video_28_clip_02\image_00099.jpg duration: 0.26225233078002933
# 29
# True: G:\Project_Theo\Project\data\test\happy\video_29_clip_01\image_00035.jpg duration: 0.24943494796752937
# 30
# True: G:\Project_Theo\Project\data\test\happy\video_30_clip_01\image_00014.jpg duration: 0.25837254524230957
# 31
# True: G:\Project_Theo\Project\data\deposit\happy\video_31_clip_01\image_00020.jpg duration: 0.26221346855163574
# 32
# True: G:\Project_Theo\Project\data\deposit\happy\video_32_clip_08\image_00236.jpg duration: 0.25844836235046387
# 33
# True: G:\Project_Theo\Project\data\deposit\happy\video_33_clip_03\image_00122.jpg duration: 0.28822278976440434
# 34
# True: G:\Project_Theo\Project\data\deposit\happy\video_34_clip_04\image_00178.jpg duration: 0.25703287124633795
# 35
# True: G:\Project_Theo\Project\data\deposit\happy\video_35_clip_03\image_00108.jpg duration: 0.24105954170227056
# 36
# True: G:\Project_Theo\Project\data\deposit\happy\video_36_clip_01\image_00028.jpg duration: 0.26109576225280767
# 37
# True: G:\Project_Theo\Project\data\deposit\happy\video_37_clip_10\image_00154.jpg duration: 0.25001931190490727
# 38
# True: G:\Project_Theo\Project\data\deposit\happy\video_38_clip_05\image_00104.jpg duration: 0.25002002716064453
# 39
# True: G:\Project_Theo\Project\data\deposit\happy\video_39_clip_07\image_00315.jpg duration: 0.28127121925354004
# 40
# True: G:\Project_Theo\Project\data\deposit\happy\video_40_clip_10\image_00208.jpg duration: 0.29689407348632813
# 41
# True: G:\Project_Theo\Project\data\deposit\happy\video_41_clip_10\image_00288.jpg duration: 0.25001692771911623
# 1
# True: G:\Project_Theo\Project\data\train\sad\video_01_clip_10\image_00497.jpg duration: 0.29689455032348633
# 2
# True: G:\Project_Theo\Project\data\train\sad\video_02_clip_08\image_00393.jpg duration: 0.25001287460327153
# 3
# True: G:\Project_Theo\Project\data\train\sad\video_03_clip_85\image_00289.jpg duration: 0.28126859664916994
# 4
# True: G:\Project_Theo\Project\data\train\sad\video_04_clip_01\image_00000.jpg duration: 0.25001454353332523
# 5
# True: G:\Project_Theo\Project\data\train\sad\video_05_clip_10\image_00499.jpg duration: 0.26564097404479984
# 6
# True: G:\Project_Theo\Project\data\train\sad\video_06_clip_06\image_00271.jpg duration: 0.28126716613769533
# 7
# True: G:\Project_Theo\Project\data\train\sad\video_07_clip_03\image_00148.jpg duration: 0.28126835823059083
# 8
# True: G:\Project_Theo\Project\data\train\sad\video_08_clip_05\image_00206.jpg duration: 0.26564407348632813
# 9
# True: G:\Project_Theo\Project\data\train\sad\video_09_clip_10\image_00489.jpg duration: 0.26564216613769533
# 10
# True: G:\Project_Theo\Project\data\train\sad\video_10_clip_03\image_00123.jpg duration: 0.28126978874206543
# 11
# True: G:\Project_Theo\Project\data\train\sad\video_11_clip_05\image_00223.jpg duration: 0.25001788139343262
# 12
# True: G:\Project_Theo\Project\data\train\sad\video_12_clip_09\image_00436.jpg duration: 0.29689407348632814
# 13
# True: G:\Project_Theo\Project\data\train\sad\video_13_clip_09\image_00400.jpg duration: 0.28126907348632813
# 14
# True: G:\Project_Theo\Project\data\train\sad\video_14_clip_10\image_00459.jpg duration: 0.29689407348632814
# 15
# True: G:\Project_Theo\Project\data\train\sad\video_15_clip_10\image_00499.jpg duration: 0.28126883506774943
# 16
# True: G:\Project_Theo\Project\data\train\sad\video_16_clip_10\image_00499.jpg duration: 0.29689598083496094
# 17
# True: G:\Project_Theo\Project\data\train\sad\video_17_clip_10\image_00499.jpg duration: 0.29689645767211914
# 18
# True: G:\Project_Theo\Project\data\train\sad\video_18_clip_10\image_00499.jpg duration: 0.28126835823059083
# 19
# True: G:\Project_Theo\Project\data\train\sad\video_19_clip_10\image_00499.jpg duration: 0.29689455032348633
# 20
# True: G:\Project_Theo\Project\data\train\sad\video_20_clip_10\image_00499.jpg duration: 0.29689383506774914
# 21
# True: G:\Project_Theo\Project\data\val\sad\video_21_clip_10\image_00499.jpg duration: 0.31252098083496094
# 22
# True: G:\Project_Theo\Project\data\val\sad\video_22_clip_10\image_00499.jpg duration: 0.31252002716064453
# 23
# True: G:\Project_Theo\Project\data\val\sad\video_23_clip_10\image_00499.jpg duration: 0.29689383506774913
# 24
# True: G:\Project_Theo\Project\data\val\sad\video_24_clip_10\image_00499.jpg duration: 0.28126859664916993
# 25
# True: G:\Project_Theo\Project\data\val\sad\video_25_clip_10\image_00499.jpg duration: 0.29689335823059083
# 26
# True: G:\Project_Theo\Project\data\test\sad\video_26_clip_10\image_00499.jpg duration: 0.28126955032348633
# 27
# True: G:\Project_Theo\Project\data\test\sad\video_27_clip_09\image_00394.jpg duration: 0.29689264297485354
# 28
# True: G:\Project_Theo\Project\data\test\sad\video_28_clip_10\image_00499.jpg duration: 0.26564240455627443
# 29
# True: G:\Project_Theo\Project\data\test\sad\video_29_clip_02\image_00067.jpg duration: 0.25001955032348633
# 30
# True: G:\Project_Theo\Project\data\test\sad\video_30_clip_02\image_00098.jpg duration: 0.31252145767211914
# 31
# True: G:\Project_Theo\Project\data\deposit\sad\video_31_clip_06\image_00273.jpg duration: 0.28126859664916993
# 32
# True: G:\Project_Theo\Project\data\deposit\sad\video_32_clip_10\image_00499.jpg duration: 0.29689311981201173
# 33
# True: G:\Project_Theo\Project\data\deposit\sad\video_33_clip_05\image_00223.jpg duration: 0.29689478874206543
# 34
# True: G:\Project_Theo\Project\data\deposit\sad\video_34_clip_01\image_00019.jpg duration: 0.23438930511474613
# 35
# True: G:\Project_Theo\Project\data\deposit\sad\video_35_clip_10\image_00489.jpg duration: 0.29689431190490723
# 36
# True: G:\Project_Theo\Project\data\deposit\sad\video_36_clip_06\image_00273.jpg duration: 0.26564335823059083
# 37
# True: G:\Project_Theo\Project\data\deposit\sad\video_37_clip_10\image_00491.jpg duration: 0.28126740455627443
# 38
# True: G:\Project_Theo\Project\data\deposit\sad\video_38_clip_01\image_00000.jpg duration: 0.25001764297485353
# 39
# True: G:\Project_Theo\Project\data\deposit\sad\video_39_clip_04\image_00180.jpg duration: 0.26564097404479983
# 40
# True: G:\Project_Theo\Project\data\deposit\sad\video_40_clip_09\image_00409.jpg duration: 0.26564192771911623
# 1
# True: G:\Project_Theo\Project\data\train\submissive\video_01_clip_04\image_00171.jpg duration: 0.26564192771911623
# 2
# True: G:\Project_Theo\Project\data\train\submissive\video_02_clip_06\image_00130.jpg duration: 0.26564502716064453
# 3
# True: G:\Project_Theo\Project\data\train\submissive\video_03_clip_01\image_00000.jpg duration: 0.25001597404479984
# 4
# True: G:\Project_Theo\Project\data\train\submissive\video_04_clip_03\image_00108.jpg duration: 0.26564025878906254
# 5
# True: G:\Project_Theo\Project\data\train\submissive\video_05_clip_09\image_00432.jpg duration: 0.28126835823059084
# 6
# True: G:\Project_Theo\Project\data\train\submissive\video_06_clip_11\image_00411.jpg duration: 0.29689431190490724
# 7
# True: G:\Project_Theo\Project\data\train\submissive\video_07_clip_06\image_00272.jpg duration: 0.31252145767211914
# 8
# True: G:\Project_Theo\Project\data\train\submissive\video_08_clip_13\image_00376.jpg duration: 0.31252098083496094
# 9
# True: G:\Project_Theo\Project\data\train\submissive\video_09_clip_07\image_00256.jpg duration: 0.26564359664916995
# 10
# True: G:\Project_Theo\Project\data\train\submissive\video_10_clip_01\image_00011.jpg duration: 0.25001263618469244
# 11
# True: G:\Project_Theo\Project\data\train\submissive\video_11_clip_04\image_00131.jpg duration: 0.29689431190490724
# 12
# True: G:\Project_Theo\Project\data\train\submissive\video_12_clip_04\image_00171.jpg duration: 0.29689550399780273
# 13
# True: G:\Project_Theo\Project\data\train\submissive\video_13_clip_05\image_00234.jpg duration: 0.25001859664916994
# 14
# True: G:\Project_Theo\Project\data\train\submissive\video_14_clip_10\image_00499.jpg duration: 0.28126788139343263
# 15
# True: G:\Project_Theo\Project\data\train\submissive\video_15_clip_10\image_00322.jpg duration: 0.25001525878906253
# 16
# True: G:\Project_Theo\Project\data\train\submissive\video_16_clip_03\image_00114.jpg duration: 0.26564264297485353
# 17
# True: G:\Project_Theo\Project\data\train\submissive\video_17_clip_02\image_00064.jpg duration: 0.25001811981201174
# 18
# True: G:\Project_Theo\Project\data\train\submissive\video_18_clip_01\image_00000.jpg duration: 0.26564216613769534
# 19
# True: G:\Project_Theo\Project\data\train\submissive\video_19_clip_46\image_00290.jpg duration: 0.28127074241638184
# 20
# True: G:\Project_Theo\Project\data\train\submissive\video_20_clip_10\image_00488.jpg duration: 0.28126907348632813
# 21
# True: G:\Project_Theo\Project\data\val\submissive\video_21_clip_10\image_00397.jpg duration: 0.25002121925354004
# 22
# True: G:\Project_Theo\Project\data\val\submissive\video_22_clip_04\image_00192.jpg duration: 0.26563930511474613
# 23
# True: G:\Project_Theo\Project\data\val\submissive\video_23_clip_08\image_00361.jpg duration: 0.31252026557922363
# 24
# True: G:\Project_Theo\Project\data\val\submissive\video_24_clip_04\image_00184.jpg duration: 0.28126788139343263
# 25
# True: G:\Project_Theo\Project\data\val\submissive\video_25_clip_08\image_00355.jpg duration: 0.28126835823059084
# 26
# True: G:\Project_Theo\Project\data\test\submissive\video_26_clip_01\image_00043.jpg duration: 0.26564240455627443
# 27
# True: G:\Project_Theo\Project\data\test\submissive\video_27_clip_09\image_00265.jpg duration: 0.26563954353332523
# 28
# True: G:\Project_Theo\Project\data\test\submissive\video_28_clip_09\image_00423.jpg duration: 0.29689598083496094
# 29
# True: G:\Project_Theo\Project\data\test\submissive\video_29_clip_01\image_00000.jpg duration: 0.25001358985900885
# 30
# True: G:\Project_Theo\Project\data\test\submissive\video_30_clip_01\image_00036.jpg duration: 0.29689455032348633
# 31
# True: G:\Project_Theo\Project\data\deposit\submissive\video_31_clip_08\image_00373.jpg duration: 0.29689359664916993
# 32
# True: G:\Project_Theo\Project\data\deposit\submissive\video_32_clip_10\image_00472.jpg duration: 0.28126907348632813
# 33
# True: G:\Project_Theo\Project\data\deposit\submissive\video_33_clip_10\image_00499.jpg duration: 0.28126740455627444
# 34
# True: G:\Project_Theo\Project\data\deposit\submissive\video_34_clip_09\image_00423.jpg duration: 0.28126859664916993
# 35
# True: G:\Project_Theo\Project\data\deposit\submissive\video_35_clip_02\image_00067.jpg duration: 0.25001907348632815
# 36
# True: G:\Project_Theo\Project\data\deposit\submissive\video_36_clip_05\image_00081.jpg duration: 0.26564264297485354
# 37
# True: G:\Project_Theo\Project\data\deposit\submissive\video_37_clip_15\image_00456.jpg duration: 0.28126835823059083
# 38
# True: G:\Project_Theo\Project\data\deposit\submissive\video_38_clip_10\image_00471.jpg duration: 0.28126978874206543
# 39
# True: G:\Project_Theo\Project\data\deposit\submissive\video_39_clip_01\image_00000.jpg duration: 0.26564216613769533
# 40
# True: G:\Project_Theo\Project\data\deposit\submissive\video_40_clip_10\image_00499.jpg duration: 0.31252193450927734
# 41
# file: G:\Project_Theo\Project\data\deposit\submissive\video_41_clip_05\image_00248.jpg duration: 0.29689598083496094

# %%
import shutil
np.set_printoptions(precision=2, suppress=True, linewidth=90)
data_path = 'data'
obj_datapath = 'object_data'
of_datapath = 'OF_data'
import random
ctg = os.listdir(data_path)
#ctg = ['happy','sad','submissive']
for x in ctg:
    count_file = 1
    listing = os.listdir(os.path.join(data_path,x))
    for file in listing:
        filename = os.listdir(os.path.join(data_path,x,file))
        for clip in filename:           
            globdir = os.path.join(data_path,x,file,clip)
            locdir = os.path.join(obj_datapath,x,file,clip)
            ofdir = os.path.join(of_datapath,x,file,clip)
            vidlist = os.listdir(globdir)
            loclist = os.listdir(locdir)
            oflist = os.listdir(ofdir)
            if(len(vidlist) < 50 and len(loclist) < 50 and len(oflist) < 50):
                shutil.rmtree(globdir)
                shutil.rmtree(locdir)                
                shutil.rmtree(ofdir) 
                print(globdir, "deleted")
                print(locdir, "deleted")
                print(ofdir, "deleted")
