# %%
"""
Train on images split into directories. This assumes we've split
our videos into frames and moved them to their respective folders.
Use keras 2+ and tensorflow 1+
Based on:
https://keras.io/preprocessing/image/
and
https://keras.io/applications/
"""
import os
# from keras.applications.inception_v3 import InceptionV3
# from keras.applications.resnet50 import ResNet50
from keras import backend as K
from keras.optimizers import SGD, Adagrad, Adam
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Model
from keras.layers import Dense, GlobalAveragePooling2D, Reshape, Activation, Multiply, GlobalMaxPooling2D
from keras.layers import LSTM, TimeDistributed, Dropout, Input, Flatten, Lambda, Concatenate, Average
from keras.callbacks import ModelCheckpoint, TensorBoard, EarlyStopping
#from utils.clr.clr_callback import * 
#from UCFdata import DataSet

from keras.layers import concatenate
from keras.regularizers import l1, l2
# Out:
# Using TensorFlow backend.

# %%
from keras.layers import Dense, Wrapper 
import keras.backend as K 


class DropConnect(Wrapper): 
    def __init__(self, layer, prob=1., **kwargs): 
        self.prob = prob 
        self.layer = layer 
        super(DropConnect, self).__init__(layer, **kwargs) 
        if 0. < self.prob < 1.: 
            self.uses_learning_phase = True 

 
    def build(self, input_shape): 
        if not self.layer.built: 
            self.layer.build(input_shape) 
            self.layer.built = True 
        super(DropConnect, self).build() 

 
    def compute_output_shape(self, input_shape): 
        return self.layer.compute_output_shape(input_shape) 

 
    def call(self, x): 
        if 0. < self.prob < 1.: 
            self.layer.kernel = K.in_train_phase(K.dropout(self.layer.kernel, self.prob), self.layer.kernel) 
            self.layer.bias = K.in_train_phase(K.dropout(self.layer.bias, self.prob), self.layer.bias) 
        return self.layer.call(x)

# %% [markdown]
# # CODE FOR INCEPTIONV3

# %%
import numpy as np
import json

from keras.utils.data_utils import get_file
from keras import backend as K

CLASS_INDEX = None
CLASS_INDEX_PATH = 'https://s3.amazonaws.com/deep-learning-models/image-models/imagenet_class_index.json'


def preprocess_input(x, dim_ordering='default'):
    if dim_ordering == 'default':
        dim_ordering = K.image_dim_ordering()
    assert dim_ordering in {'tf', 'th'}

    if dim_ordering == 'th':
        x[:, 0, :, :] -= 103.939
        x[:, 1, :, :] -= 116.779
        x[:, 2, :, :] -= 123.68
        # 'RGB'->'BGR'
        x = x[:, ::-1, :, :]
    else:
        x[:, :, :, 0] -= 103.939
        x[:, :, :, 1] -= 116.779
        x[:, :, :, 2] -= 123.68
        # 'RGB'->'BGR'
        x = x[:, :, :, ::-1]
    return x


def decode_predictions(preds, top=5):
    global CLASS_INDEX
    if len(preds.shape) != 2 or preds.shape[1] != 1000:
        raise ValueError('`decode_predictions` expects '
                         'a batch of predictions '
                         '(i.e. a 2D array of shape (samples, 1000)). '
                         'Found array with shape: ' + str(preds.shape))
    if CLASS_INDEX is None:
        fpath = get_file('imagenet_class_index.json',
                         CLASS_INDEX_PATH,
                         cache_subdir='models')
        CLASS_INDEX = json.load(open(fpath))
    results = []
    for pred in preds:
        top_indices = pred.argsort()[-top:][::-1]
        result = [tuple(CLASS_INDEX[str(i)]) + (pred[i],) for i in top_indices]
        results.append(result)
    return results

# %%
from __future__ import print_function

import numpy as np
import warnings

from keras.models import Model
from keras.layers import Flatten, Dense, Input, BatchNormalization, merge
from keras.layers import Convolution2D, MaxPooling2D, AveragePooling2D
from keras.preprocessing import image
from keras.utils.layer_utils import convert_all_kernels_in_model
from keras.utils.data_utils import get_file
from keras import backend as K


TH_WEIGHTS_PATH = 'https://github.com/fchollet/deep-learning-models/releases/download/v0.2/inception_v3_weights_th_dim_ordering_th_kernels.h5'
TF_WEIGHTS_PATH = 'https://github.com/fchollet/deep-learning-models/releases/download/v0.2/inception_v3_weights_tf_dim_ordering_tf_kernels.h5'
TH_WEIGHTS_PATH_NO_TOP = 'https://github.com/fchollet/deep-learning-models/releases/download/v0.2/inception_v3_weights_th_dim_ordering_th_kernels_notop.h5'
TF_WEIGHTS_PATH_NO_TOP = 'https://github.com/fchollet/deep-learning-models/releases/download/v0.2/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5'


def conv2d_bn(x, nb_filter, nb_row, nb_col,
              border_mode='same', subsample=(1, 1),
              name=None):
    '''Utility function to apply conv + BN.
    '''
    if name is not None:
        bn_name = name + '_bn'
        conv_name = name + '_conv'
    else:
        bn_name = None
        conv_name = None
    if K.image_dim_ordering() == 'th':
        bn_axis = 1
    else:
        bn_axis = 3
    x = Convolution2D(nb_filter, nb_row, nb_col,
                      subsample=subsample,
                      activation='relu',
                      border_mode=border_mode,
                      name=conv_name)(x)
    x = BatchNormalization(axis=bn_axis, name=bn_name)(x)
    return x


def InceptionV3(include_top=True, weights='imagenet',
                input_tensor=None):
    '''Instantiate the Inception v3 architecture,
    optionally loading weights pre-trained
    on ImageNet. Note that when using TensorFlow,
    for best performance you should set
    `image_dim_ordering="tf"` in your Keras config
    at ~/.keras/keras.json.
    The model and the weights are compatible with both
    TensorFlow and Theano. The dimension ordering
    convention used by the model is the one
    specified in your Keras config file.
    Note that the default input image size for this model is 299x299.
    # Arguments
        include_top: whether to include the 3 fully-connected
            layers at the top of the network.
        weights: one of `None` (random initialization)
            or "imagenet" (pre-training on ImageNet).
        input_tensor: optional Keras tensor (i.e. output of `layers.Input()`)
            to use as image input for the model.
    # Returns
        A Keras model instance.
    '''
    if weights not in {'imagenet', None}:
        raise ValueError('The `weights` argument should be either '
                         '`None` (random initialization) or `imagenet` '
                         '(pre-training on ImageNet).')
    # Determine proper input shape
    if K.image_dim_ordering() == 'th':
        if include_top:
            input_shape = (3, 299, 299)
        else:
            input_shape = (3, None, None)
    else:
        if include_top:
            input_shape = (299, 299, 3)
        else:
            input_shape = (None, None, 3)

    if input_tensor is None:
        img_input = Input(shape=input_shape)
    else:
        if not K.is_keras_tensor(input_tensor):
            img_input = Input(tensor=input_tensor)
        else:
            img_input = input_tensor

    if K.image_dim_ordering() == 'th':
        channel_axis = 1
    else:
        channel_axis = 3

    x = conv2d_bn(img_input, 32, 3, 3, subsample=(2, 2), border_mode='valid')
    x = conv2d_bn(x, 32, 3, 3, border_mode='valid')
    x = conv2d_bn(x, 64, 3, 3)
    x = MaxPooling2D((3, 3), strides=(2, 2))(x)

    x = conv2d_bn(x, 80, 1, 1, border_mode='valid')
    x = conv2d_bn(x, 192, 3, 3, border_mode='valid')
    x = MaxPooling2D((3, 3), strides=(2, 2))(x)

    # mixed 0, 1, 2: 35 x 35 x 256
    for i in range(3):
        branch1x1 = conv2d_bn(x, 64, 1, 1)

        branch5x5 = conv2d_bn(x, 48, 1, 1)
        branch5x5 = conv2d_bn(branch5x5, 64, 5, 5)

        branch3x3dbl = conv2d_bn(x, 64, 1, 1)
        branch3x3dbl = conv2d_bn(branch3x3dbl, 96, 3, 3)
        branch3x3dbl = conv2d_bn(branch3x3dbl, 96, 3, 3)

        branch_pool = AveragePooling2D(
            (3, 3), strides=(1, 1), border_mode='same')(x)
        branch_pool = conv2d_bn(branch_pool, 32, 1, 1)
        x = concatenate([branch1x1, branch5x5, branch3x3dbl, branch_pool])

    # mixed 3: 17 x 17 x 768
    branch3x3 = conv2d_bn(x, 384, 3, 3, subsample=(2, 2), border_mode='valid')

    branch3x3dbl = conv2d_bn(x, 64, 1, 1)
    branch3x3dbl = conv2d_bn(branch3x3dbl, 96, 3, 3)
    branch3x3dbl = conv2d_bn(branch3x3dbl, 96, 3, 3,
                             subsample=(2, 2), border_mode='valid')

    branch_pool = MaxPooling2D((3, 3), strides=(2, 2))(x)
    x = concatenate([branch3x3, branch3x3dbl, branch_pool])

    # mixed 4: 17 x 17 x 768
    branch1x1 = conv2d_bn(x, 192, 1, 1)

    branch7x7 = conv2d_bn(x, 128, 1, 1)
    branch7x7 = conv2d_bn(branch7x7, 128, 1, 7)
    branch7x7 = conv2d_bn(branch7x7, 192, 7, 1)

    branch7x7dbl = conv2d_bn(x, 128, 1, 1)
    branch7x7dbl = conv2d_bn(branch7x7dbl, 128, 7, 1)
    branch7x7dbl = conv2d_bn(branch7x7dbl, 128, 1, 7)
    branch7x7dbl = conv2d_bn(branch7x7dbl, 128, 7, 1)
    branch7x7dbl = conv2d_bn(branch7x7dbl, 192, 1, 7)

    branch_pool = AveragePooling2D((3, 3), strides=(1, 1), border_mode='same')(x)
    branch_pool = conv2d_bn(branch_pool, 192, 1, 1)
    x = concatenate([branch1x1, branch7x7, branch7x7dbl, branch_pool])

    # mixed 5, 6: 17 x 17 x 768
    for i in range(2):
        branch1x1 = conv2d_bn(x, 192, 1, 1)

        branch7x7 = conv2d_bn(x, 160, 1, 1)
        branch7x7 = conv2d_bn(branch7x7, 160, 1, 7)
        branch7x7 = conv2d_bn(branch7x7, 192, 7, 1)

        branch7x7dbl = conv2d_bn(x, 160, 1, 1)
        branch7x7dbl = conv2d_bn(branch7x7dbl, 160, 7, 1)
        branch7x7dbl = conv2d_bn(branch7x7dbl, 160, 1, 7)
        branch7x7dbl = conv2d_bn(branch7x7dbl, 160, 7, 1)
        branch7x7dbl = conv2d_bn(branch7x7dbl, 192, 1, 7)

        branch_pool = AveragePooling2D(
            (3, 3), strides=(1, 1), border_mode='same')(x)
        branch_pool = conv2d_bn(branch_pool, 192, 1, 1)
        x = concatenate([branch1x1, branch7x7, branch7x7dbl, branch_pool])

    # mixed 7: 17 x 17 x 768
    branch1x1 = conv2d_bn(x, 192, 1, 1)

    branch7x7 = conv2d_bn(x, 192, 1, 1)
    branch7x7 = conv2d_bn(branch7x7, 192, 1, 7)
    branch7x7 = conv2d_bn(branch7x7, 192, 7, 1)

    branch7x7dbl = conv2d_bn(x, 160, 1, 1)
    branch7x7dbl = conv2d_bn(branch7x7dbl, 192, 7, 1)
    branch7x7dbl = conv2d_bn(branch7x7dbl, 192, 1, 7)
    branch7x7dbl = conv2d_bn(branch7x7dbl, 192, 7, 1)
    branch7x7dbl = conv2d_bn(branch7x7dbl, 192, 1, 7)

    branch_pool = AveragePooling2D((3, 3), strides=(1, 1), border_mode='same')(x)
    branch_pool = conv2d_bn(branch_pool, 192, 1, 1)
    x = concatenate([branch1x1, branch7x7, branch7x7dbl, branch_pool])

    # mixed 8: 8 x 8 x 1280
    branch3x3 = conv2d_bn(x, 192, 1, 1)
    branch3x3 = conv2d_bn(branch3x3, 320, 3, 3,
                          subsample=(2, 2), border_mode='valid')

    branch7x7x3 = conv2d_bn(x, 192, 1, 1)
    branch7x7x3 = conv2d_bn(branch7x7x3, 192, 1, 7)
    branch7x7x3 = conv2d_bn(branch7x7x3, 192, 7, 1)
    branch7x7x3 = conv2d_bn(branch7x7x3, 192, 3, 3,
                            subsample=(2, 2), border_mode='valid')

    branch_pool = AveragePooling2D((3, 3), strides=(2, 2))(x)
    x = concatenate([branch3x3, branch7x7x3, branch_pool])

    # mixed 9: 8 x 8 x 2048
    for i in range(2):
        branch1x1 = conv2d_bn(x, 320, 1, 1)

        branch3x3 = conv2d_bn(x, 384, 1, 1)
        branch3x3_1 = conv2d_bn(branch3x3, 384, 1, 3)
        branch3x3_2 = conv2d_bn(branch3x3, 384, 3, 1)
        branch3x3 = concatenate([branch3x3_1, branch3x3_2])

        branch3x3dbl = conv2d_bn(x, 448, 1, 1)
        branch3x3dbl = conv2d_bn(branch3x3dbl, 384, 3, 3)
        branch3x3dbl_1 = conv2d_bn(branch3x3dbl, 384, 1, 3)
        branch3x3dbl_2 = conv2d_bn(branch3x3dbl, 384, 3, 1)
        branch3x3dbl = concatenate([branch3x3dbl_1, branch3x3dbl_2])

        branch_pool = AveragePooling2D(
            (3, 3), strides=(1, 1), border_mode='same')(x)
        branch_pool = conv2d_bn(branch_pool, 192, 1, 1)
        x = concatenate([branch1x1, branch3x3, branch3x3dbl, branch_pool])

    if include_top:
        # Classification block
        x = AveragePooling2D((8, 8), strides=(8, 8), name='avg_pool')(x)
        x = Flatten(name='flatten')(x)
        x = Dense(1000, activation='softmax', name='predictions')(x)

    # Create model
    model = Model(img_input, x)

    # load weights
    if weights == 'imagenet':
        if K.image_dim_ordering() == 'th':
            if include_top:
                weights_path = get_file('inception_v3_weights_th_dim_ordering_th_kernels.h5',
                                        TH_WEIGHTS_PATH,
                                        cache_subdir='models',
                                        md5_hash='b3baf3070cc4bf476d43a2ea61b0ca5f')
            else:
                weights_path = get_file('inception_v3_weights_th_dim_ordering_th_kernels_notop.h5',
                                        TH_WEIGHTS_PATH_NO_TOP,
                                        cache_subdir='models',
                                        md5_hash='79aaa90ab4372b4593ba3df64e142f05')
            model.load_weights(weights_path)
            if K.backend() == 'tensorflow':
                warnings.warn('You are using the TensorFlow backend, yet you '
                              'are using the Theano '
                              'image dimension ordering convention '
                              '(`image_dim_ordering="th"`). '
                              'For best performance, set '
                              '`image_dim_ordering="tf"` in '
                              'your Keras config '
                              'at ~/.keras/keras.json.')
                convert_all_kernels_in_model(model)
        else:
            if include_top:
                weights_path = get_file('inception_v3_weights_tf_dim_ordering_tf_kernels.h5',
                                        TF_WEIGHTS_PATH,
                                        cache_subdir='models',
                                        md5_hash='fe114b3ff2ea4bf891e9353d1bbfb32f')
            else:
                weights_path = get_file('inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5',
                                        TF_WEIGHTS_PATH_NO_TOP,
                                        cache_subdir='models',
                                        md5_hash='2f3609166de1d967d1a481094754f691')
            model.load_weights(weights_path)
            if K.backend() == 'theano':
                convert_all_kernels_in_model(model)
    return model


def preprocess_input(x):
    x /= 255.
    x -= 0.5
    x *= 2.
    return x

# %% [markdown]
# # END OF CODE FOR INCEPTIONV3

# %%
class color:
    PURPLE = '\033[95m'
    CYAN = '\033[96m'
    DARKCYAN = '\033[36m'
    BLUE = '\033[94m'
    GREEN = '\033[92m'
    YELLOW = '\033[93m'
    RED = '\033[91m'
    BOLD = '\033[1m'
    UNDERLINE = '\033[4m'
    END = '\033[0m'

# %%
# def get_generators():
#     datagen = ImageDataGenerator(rescale=1. / 255)
#     train_generator = datagen.flow_from_directory(
#           'data/train',
#           target_size=(224, 224),
#           batch_size=batch_size,
#           class_mode='categorical',  # this means our generator will only yield batches of data, no labels
#           shuffle=True,
#           classes=['angry','happy', 'sad', 'submissive'])

#     validation_generator = datagen.flow_from_directory(
#           'data/val',
#           target_size=(224, 224),
#           batch_size=batch_size,
#           class_mode='categorical',  # this means our generator will only yield batches of data, no labels
#           shuffle=True,
#           classes=['angry','happy','sad', 'submissive'])
#     return train_generator, validation_generator

# %%
def generate_generator_multiple(generator,dir1, dir2, dir3, batch_size, img_height,img_width):
    genX1 = generator.flow_from_directory(dir1,
                                          target_size = (img_height,img_width),
                                          class_mode = 'categorical',
                                          batch_size = batch_size,
                                          shuffle=False, 
                                          classes=['angry','happy','sad', 'submissive'],
                                          seed=7)
    
    genX2 = generator.flow_from_directory(dir2,
                                          target_size = (img_height,img_width),
                                          class_mode = 'categorical',
                                          batch_size = batch_size,
                                          shuffle=False, 
                                          classes=['angry','happy','sad', 'submissive'],
                                          seed=7)
    
    genX3 = generator.flow_from_directory(dir3,
                                          target_size = (img_height,img_width),
                                          class_mode = 'categorical',
                                          batch_size = batch_size,
                                          shuffle=False, 
                                          classes=['angry','happy','sad', 'submissive'],
                                          seed=7)
    while True:
            X1i = genX1.next()
            X2i = genX2.next()
            X3i = genX3.next()
            yield [X1i[0], X2i[0], X3i[0]], X2i[1]  #Yield both images and their mutual label

# %%
from keras.layers import Input
from keras.layers import Dense
from keras.layers import Convolution2D
from keras.layers import MaxPooling2D
from keras.layers import BatchNormalization
from keras.layers import Activation
from keras.layers import Dropout
from keras.layers import Flatten
from keras.models import Model
import os


def CNN(input_shape, classes, weights_dir, include_top=True):
    '''
    The CNN for optical flow input.
    Since optical flow is not a common image, we cannot finetune pre-trained ResNet (The weights trained on imagenet is
    for images and thus is meaningless for optical flow)
    :param input_shape: the shape of optical flow input
    :param classes: number of classes
    :return:
    '''
    optical_flow_input = Input(shape=input_shape)

    x = Convolution2D(96, kernel_size=(7, 7), strides=(2, 2), padding='same', name='tmp_conv1')(optical_flow_input)
    x = DropConnect(Dense(96, activation='relu'), prob=0.5)(x)
    x = BatchNormalization(axis=3)(x)
    x = MaxPooling2D(pool_size=(2, 2))(x)

    x = Convolution2D(256, kernel_size=(5, 5), strides=(2, 2), padding='same', name='tmp_conv2')(x)
    x = DropConnect(Dense(256, activation='relu'), prob=0.5)(x)
    x = BatchNormalization(axis=3)(x)
    x = MaxPooling2D(pool_size=(2, 2))(x)

    x = Convolution2D(512, kernel_size=(3, 3), strides=(1, 1), padding='same', name='tmp_conv3')(x)
    x = DropConnect(Dense(512, activation='relu'), prob=0.5)(x)
    x = BatchNormalization(axis=3)(x)

    x = Convolution2D(512, kernel_size=(3, 3), strides=(1, 1), padding='same', name='tmp_conv4')(x)
    x = DropConnect(Dense(512, activation='relu'), prob=0.5)(x)
    x = BatchNormalization(axis=3)(x)

    x = Convolution2D(512, kernel_size=(3, 3), strides=(1, 1), padding='same', name='tmp_conv5')(x)
    x = DropConnect(Dense(512, activation='relu'), prob=0.5)(x)
    x = BatchNormalization(axis=3)(x)
    x = MaxPooling2D(pool_size=(2, 2))(x)

#     x = Flatten()(x)
#     x = Dense(4096, activation='relu', name='tmp_fc6')(x)
#     x = Dropout(0.9)(x)

#     x = Dense(2048, activation='relu', name='tmp_fc7')(x)
#     x = Dropout(0.9)(x)

    if include_top:
        x = Dense(classes, activation='softmax', name='tmp_fc101')(x)

    
    
    model = Model(inputs=optical_flow_input, outputs=x, name='temporal_CNN')

    
    if weights_dir == 'imagenet':
        if K.image_dim_ordering() == 'th':
            if include_top:
                weights_path = get_file('inception_v3_weights_th_dim_ordering_th_kernels.h5',
                                        TH_WEIGHTS_PATH,
                                        cache_subdir='models',
                                        md5_hash='b3baf3070cc4bf476d43a2ea61b0ca5f')
            else:
                weights_path = get_file('inception_v3_weights_th_dim_ordering_th_kernels_notop.h5',
                                        TH_WEIGHTS_PATH_NO_TOP,
                                        cache_subdir='models',
                                        md5_hash='79aaa90ab4372b4593ba3df64e142f05')
            model.load_weights(weights_path)
            if K.backend() == 'tensorflow':
                warnings.warn('You are using the TensorFlow backend, yet you '
                              'are using the Theano '
                              'image dimension ordering convention '
                              '(`image_dim_ordering="th"`). '
                              'For best performance, set '
                              '`image_dim_ordering="tf"` in '
                              'your Keras config '
                              'at ~/.keras/keras.json.')
                convert_all_kernels_in_model(model)
    else:
        if os.path.exists(weights_dir):
            model.load_weights(weights_dir, by_name=True)

    return model

# %%
def get_model(weights='imagenet'):
    # create the base pre-trained model
    base_model_local = InceptionV3(weights=weights, include_top=False)
    x1 = base_model_local.output
    x1 = GlobalAveragePooling2D()(x1)
    x1 = Dense(256, activation='relu')(x1)
    x1 = DropConnect(Dense(256, activation='relu'), prob=0.9)(x1)
   
                     

    base_model_globallstm = InceptionV3(weights=weights, include_top=False)
    x2 = base_model_globallstm.output
    x2 = GlobalAveragePooling2D()(x2)
    x2 = Dense(256, activation='relu')(x2)
    x2 = DropConnect(Dense(256, activation='relu'), prob=0.9)(x2)

          
                                   
                                   
    base_model_optical = CNN((224,224,3),4,'', include_top=False)                              
    x3 = base_model_optical.output
    x3 = Convolution2D(2048, kernel_size=(3, 3), strides=(1, 1))(x3)
    x3 = Reshape((25,2048))(x3)
    x3 = LSTM(256,dropout=0.2,input_shape=(25,2048))(x3)
    x3 = DropConnect(Dense(256, activation='relu'), prob=0.9)(x3)

    
                                   
    x = Average(name='gadogado_layer')([x1, x2, x3])                               
    x = Dense(1024, activation='relu')(x)
    x = DropConnect(Dense(1024, activation='relu'), prob=0.9)(x)
#     x = Dropout(0.9)(x)
    
    predictions = Dense(4, activation='softmax')(x)

    # this is the model we will train
    model = Model(inputs=[base_model_local.input,base_model_globallstm.input,base_model_optical.input], outputs=predictions)

    for layer in base_model_local.layers:
        layer.trainable = False
    for layer in base_model_globallstm.layers:
        layer.trainable = False
#     for layer in base_model_optical.layers:
#         layer.trainable = False

    # compile the model (should be done *after* setting layers to non-trainable)
    model.compile(optimizer=Adagrad(lr=0.0001, decay = 1e-3), loss='categorical_crossentropy', metrics=['accuracy'])

    return model

# %%
img_height = 224
img_width = 224
train_data = 23750
val_data = 7100
batch_size = 25
# Helper: Save the min val_loss model in each epoch.

checkpointer = ModelCheckpoint(
    filepath='incept(global)_incept(local)_incept(of)_avg.{epoch:03d}-{val_loss:.2f}-{val_acc:.2f}.hdf5', 
    #save format is epoch-loss-acc-time-date(mmddyyyy)
    verbose=1,
    monitor='val_acc',
    save_best_only=True)

# Helper: Stop when we stop learning.
# patience: number of epochs with no improvement after which training will be stopped.
early_stopper = EarlyStopping(patience=10)

#Cyclic Learning Rate. base lr is the minimum lowest bound
#clr_triangular = CyclicLR(mode='triangular', base_lr = 0.00005)
# Helper: TensorBoard
tensorboard = TensorBoard(log_dir='utils/logs/')
traindatagen = ImageDataGenerator(rescale=1. / 255)
valdatagen = ImageDataGenerator(rescale=1. / 255)
train_generator=generate_generator_multiple(generator=traindatagen,
                                           dir1='data/train',
                                           dir2='object_data/train',
                                            dir3='OF_data/train',
                                            batch_size=batch_size,
                                           img_height=img_height,
                                           img_width=img_width)       
     
validation_generator=generate_generator_multiple(valdatagen,
                                          dir1='data/val',
                                          dir2='object_data/val',
                                            dir3='OF_data/val',
                                          batch_size=batch_size,
                                          img_height=img_height,
                                          img_width=img_width)     
model = get_model()
model.summary()
nb_epoch = 30
model = model.fit_generator(
    train_generator,
    steps_per_epoch=train_data/batch_size,
    validation_data=validation_generator,
    validation_steps=val_data/batch_size,
    epochs=nb_epoch,
    callbacks=[checkpointer])
# Out:
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\tfgpu\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# C:\ProgramData\Anaconda3\envs\tfgpu\lib\site-packages\ipykernel_launcher.py:40: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), activation="relu", name=None, strides=(2, 2), padding="valid")`
# C:\ProgramData\Anaconda3\envs\tfgpu\lib\site-packages\ipykernel_launcher.py:40: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), activation="relu", name=None, strides=(1, 1), padding="valid")`
# C:\ProgramData\Anaconda3\envs\tfgpu\lib\site-packages\ipykernel_launcher.py:40: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (3, 3), activation="relu", name=None, strides=(1, 1), padding="same")`
# C:\ProgramData\Anaconda3\envs\tfgpu\lib\site-packages\ipykernel_launcher.py:40: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(80, (1, 1), activation="relu", name=None, strides=(1, 1), padding="valid")`
# C:\ProgramData\Anaconda3\envs\tfgpu\lib\site-packages\ipykernel_launcher.py:40: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(192, (3, 3), activation="relu", name=None, strides=(1, 1), padding="valid")`
# C:\ProgramData\Anaconda3\envs\tfgpu\lib\site-packages\ipykernel_launcher.py:40: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (1, 1), activation="relu", name=None, strides=(1, 1), padding="same")`
# C:\ProgramData\Anaconda3\envs\tfgpu\lib\site-packages\ipykernel_launcher.py:40: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(48, (1, 1), activation="relu", name=None, strides=(1, 1), padding="same")`
# C:\ProgramData\Anaconda3\envs\tfgpu\lib\site-packages\ipykernel_launcher.py:40: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (5, 5), activation="relu", name=None, strides=(1, 1), padding="same")`
# C:\ProgramData\Anaconda3\envs\tfgpu\lib\site-packages\ipykernel_launcher.py:40: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(96, (3, 3), activation="relu", name=None, strides=(1, 1), padding="same")`
# C:\ProgramData\Anaconda3\envs\tfgpu\lib\site-packages\ipykernel_launcher.py:118: UserWarning: Update your `AveragePooling2D` call to the Keras 2 API: `AveragePooling2D((3, 3), strides=(1, 1), padding="same")`
# C:\ProgramData\Anaconda3\envs\tfgpu\lib\site-packages\ipykernel_launcher.py:40: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (1, 1), activation="relu", name=None, strides=(1, 1), padding="same")`
# C:\ProgramData\Anaconda3\envs\tfgpu\lib\site-packages\ipykernel_launcher.py:40: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(384, (3, 3), activation="relu", name=None, strides=(2, 2), padding="valid")`
# C:\ProgramData\Anaconda3\envs\tfgpu\lib\site-packages\ipykernel_launcher.py:40: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(96, (3, 3), activation="relu", name=None, strides=(2, 2), padding="valid")`
# C:\ProgramData\Anaconda3\envs\tfgpu\lib\site-packages\ipykernel_launcher.py:40: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(192, (1, 1), activation="relu", name=None, strides=(1, 1), padding="same")`
# C:\ProgramData\Anaconda3\envs\tfgpu\lib\site-packages\ipykernel_launcher.py:40: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), activation="relu", name=None, strides=(1, 1), padding="same")`
# C:\ProgramData\Anaconda3\envs\tfgpu\lib\site-packages\ipykernel_launcher.py:40: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 7), activation="relu", name=None, strides=(1, 1), padding="same")`
# C:\ProgramData\Anaconda3\envs\tfgpu\lib\site-packages\ipykernel_launcher.py:40: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(192, (7, 1), activation="relu", name=None, strides=(1, 1), padding="same")`
# C:\ProgramData\Anaconda3\envs\tfgpu\lib\site-packages\ipykernel_launcher.py:40: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (7, 1), activation="relu", name=None, strides=(1, 1), padding="same")`
# C:\ProgramData\Anaconda3\envs\tfgpu\lib\site-packages\ipykernel_launcher.py:40: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(192, (1, 7), activation="relu", name=None, strides=(1, 1), padding="same")`
# C:\ProgramData\Anaconda3\envs\tfgpu\lib\site-packages\ipykernel_launcher.py:146: UserWarning: Update your `AveragePooling2D` call to the Keras 2 API: `AveragePooling2D((3, 3), strides=(1, 1), padding="same")`
# C:\ProgramData\Anaconda3\envs\tfgpu\lib\site-packages\ipykernel_launcher.py:40: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(160, (1, 1), activation="relu", name=None, strides=(1, 1), padding="same")`
# C:\ProgramData\Anaconda3\envs\tfgpu\lib\site-packages\ipykernel_launcher.py:40: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(160, (1, 7), activation="relu", name=None, strides=(1, 1), padding="same")`
# C:\ProgramData\Anaconda3\envs\tfgpu\lib\site-packages\ipykernel_launcher.py:40: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(160, (7, 1), activation="relu", name=None, strides=(1, 1), padding="same")`
# C:\ProgramData\Anaconda3\envs\tfgpu\lib\site-packages\ipykernel_launcher.py:165: UserWarning: Update your `AveragePooling2D` call to the Keras 2 API: `AveragePooling2D((3, 3), strides=(1, 1), padding="same")`
# C:\ProgramData\Anaconda3\envs\tfgpu\lib\site-packages\ipykernel_launcher.py:182: UserWarning: Update your `AveragePooling2D` call to the Keras 2 API: `AveragePooling2D((3, 3), strides=(1, 1), padding="same")`
# C:\ProgramData\Anaconda3\envs\tfgpu\lib\site-packages\ipykernel_launcher.py:40: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(320, (3, 3), activation="relu", name=None, strides=(2, 2), padding="valid")`
# C:\ProgramData\Anaconda3\envs\tfgpu\lib\site-packages\ipykernel_launcher.py:40: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(192, (3, 3), activation="relu", name=None, strides=(2, 2), padding="valid")`
# C:\ProgramData\Anaconda3\envs\tfgpu\lib\site-packages\ipykernel_launcher.py:40: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(320, (1, 1), activation="relu", name=None, strides=(1, 1), padding="same")`
# C:\ProgramData\Anaconda3\envs\tfgpu\lib\site-packages\ipykernel_launcher.py:40: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(384, (1, 1), activation="relu", name=None, strides=(1, 1), padding="same")`
# C:\ProgramData\Anaconda3\envs\tfgpu\lib\site-packages\ipykernel_launcher.py:40: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(384, (1, 3), activation="relu", name=None, strides=(1, 1), padding="same")`
# C:\ProgramData\Anaconda3\envs\tfgpu\lib\site-packages\ipykernel_launcher.py:40: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(384, (3, 1), activation="relu", name=None, strides=(1, 1), padding="same")`
# C:\ProgramData\Anaconda3\envs\tfgpu\lib\site-packages\ipykernel_launcher.py:40: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(448, (1, 1), activation="relu", name=None, strides=(1, 1), padding="same")`
# C:\ProgramData\Anaconda3\envs\tfgpu\lib\site-packages\ipykernel_launcher.py:40: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(384, (3, 3), activation="relu", name=None, strides=(1, 1), padding="same")`
# C:\ProgramData\Anaconda3\envs\tfgpu\lib\site-packages\ipykernel_launcher.py:216: UserWarning: Update your `AveragePooling2D` call to the Keras 2 API: `AveragePooling2D((3, 3), strides=(1, 1), padding="same")`
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\tfgpu\lib\site-packages\keras\backend\tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, None, None, 3 0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            (None, None, None, 3 0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, None, None, 3 896         input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_95 (Conv2D)              (None, None, None, 3 896         input_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, None, None, 3 128         conv2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_95 (BatchNo (None, None, None, 3 128         conv2d_95[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, None, None, 3 9248        batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_96 (Conv2D)              (None, None, None, 3 9248        batch_normalization_95[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, None, None, 3 128         conv2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_96 (BatchNo (None, None, None, 3 128         conv2d_96[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, None, None, 6 18496       batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_97 (Conv2D)              (None, None, None, 6 18496       batch_normalization_96[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, None, None, 6 256         conv2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_97 (BatchNo (None, None, None, 6 256         conv2d_97[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, None, None, 6 0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, None, None, 6 0           batch_normalization_97[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, None, None, 8 5200        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_98 (Conv2D)              (None, None, None, 8 5200        max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, None, None, 8 320         conv2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_98 (BatchNo (None, None, None, 8 320         conv2d_98[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, None, None, 1 138432      batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_99 (Conv2D)              (None, None, None, 1 138432      batch_normalization_98[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, None, None, 1 768         conv2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_99 (BatchNo (None, None, None, 1 768         conv2d_99[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, None, None, 1 0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, None, None, 1 0           batch_normalization_99[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, None, None, 6 12352       max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_103 (Conv2D)             (None, None, None, 6 12352       max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, None, None, 6 256         conv2d_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_103 (BatchN (None, None, None, 6 256         conv2d_103[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, None, None, 4 9264        max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, None, None, 9 55392       batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_101 (Conv2D)             (None, None, None, 4 9264        max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_104 (Conv2D)             (None, None, None, 9 55392       batch_normalization_103[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, None, None, 4 192         conv2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, None, None, 9 384         conv2d_10[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, None, None, 1 0           max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_101 (BatchN (None, None, None, 4 192         conv2d_101[0][0]
# __________________________________________________________________________________________________
# batch_normalization_104 (BatchN (None, None, None, 9 384         conv2d_104[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_11 (AveragePo (None, None, None, 1 0           max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, None, None, 6 12352       max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, None, None, 6 76864       batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, None, None, 9 83040       batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, None, None, 3 6176        average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_100 (Conv2D)             (None, None, None, 6 12352       max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_102 (Conv2D)             (None, None, None, 6 76864       batch_normalization_101[0][0]
# __________________________________________________________________________________________________
# conv2d_105 (Conv2D)             (None, None, None, 9 83040       batch_normalization_104[0][0]
# __________________________________________________________________________________________________
# conv2d_106 (Conv2D)             (None, None, None, 3 6176        average_pooling2d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, None, None, 6 256         conv2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, None, None, 6 256         conv2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, None, None, 9 384         conv2d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, None, None, 3 128         conv2d_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_100 (BatchN (None, None, None, 6 256         conv2d_100[0][0]
# __________________________________________________________________________________________________
# batch_normalization_102 (BatchN (None, None, None, 6 256         conv2d_102[0][0]
# __________________________________________________________________________________________________
# batch_normalization_105 (BatchN (None, None, None, 9 384         conv2d_105[0][0]
# __________________________________________________________________________________________________
# batch_normalization_106 (BatchN (None, None, None, 3 128         conv2d_106[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, None, None, 2 0           batch_normalization_6[0][0]
#                                                                  batch_normalization_8[0][0]
#                                                                  batch_normalization_11[0][0]
#                                                                  batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# concatenate_16 (Concatenate)    (None, None, None, 2 0           batch_normalization_100[0][0]
#                                                                  batch_normalization_102[0][0]
#                                                                  batch_normalization_105[0][0]
#                                                                  batch_normalization_106[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, None, None, 6 16448       concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_110 (Conv2D)             (None, None, None, 6 16448       concatenate_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, None, None, 6 256         conv2d_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_110 (BatchN (None, None, None, 6 256         conv2d_110[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, None, None, 4 12336       concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, None, None, 9 55392       batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_108 (Conv2D)             (None, None, None, 4 12336       concatenate_16[0][0]
# __________________________________________________________________________________________________
# conv2d_111 (Conv2D)             (None, None, None, 9 55392       batch_normalization_110[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, None, None, 4 192         conv2d_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, None, None, 9 384         conv2d_17[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_2 (AveragePoo (None, None, None, 2 0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_108 (BatchN (None, None, None, 4 192         conv2d_108[0][0]
# __________________________________________________________________________________________________
# batch_normalization_111 (BatchN (None, None, None, 9 384         conv2d_111[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_12 (AveragePo (None, None, None, 2 0           concatenate_16[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, None, None, 6 16448       concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, None, None, 6 76864       batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, None, None, 9 83040       batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, None, None, 3 8224        average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_107 (Conv2D)             (None, None, None, 6 16448       concatenate_16[0][0]
# __________________________________________________________________________________________________
# conv2d_109 (Conv2D)             (None, None, None, 6 76864       batch_normalization_108[0][0]
# __________________________________________________________________________________________________
# conv2d_112 (Conv2D)             (None, None, None, 9 83040       batch_normalization_111[0][0]
# __________________________________________________________________________________________________
# conv2d_113 (Conv2D)             (None, None, None, 3 8224        average_pooling2d_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, None, None, 6 256         conv2d_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, None, None, 6 256         conv2d_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, None, None, 9 384         conv2d_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, None, None, 3 128         conv2d_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_107 (BatchN (None, None, None, 6 256         conv2d_107[0][0]
# __________________________________________________________________________________________________
# batch_normalization_109 (BatchN (None, None, None, 6 256         conv2d_109[0][0]
# __________________________________________________________________________________________________
# batch_normalization_112 (BatchN (None, None, None, 9 384         conv2d_112[0][0]
# __________________________________________________________________________________________________
# batch_normalization_113 (BatchN (None, None, None, 3 128         conv2d_113[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, None, None, 2 0           batch_normalization_13[0][0]
#                                                                  batch_normalization_15[0][0]
#                                                                  batch_normalization_18[0][0]
#                                                                  batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# concatenate_17 (Concatenate)    (None, None, None, 2 0           batch_normalization_107[0][0]
#                                                                  batch_normalization_109[0][0]
#                                                                  batch_normalization_112[0][0]
#                                                                  batch_normalization_113[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, None, None, 6 16448       concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_117 (Conv2D)             (None, None, None, 6 16448       concatenate_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, None, None, 6 256         conv2d_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_117 (BatchN (None, None, None, 6 256         conv2d_117[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, None, None, 4 12336       concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, None, None, 9 55392       batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# conv2d_115 (Conv2D)             (None, None, None, 4 12336       concatenate_17[0][0]
# __________________________________________________________________________________________________
# conv2d_118 (Conv2D)             (None, None, None, 9 55392       batch_normalization_117[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, None, None, 4 192         conv2d_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, None, None, 9 384         conv2d_24[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_3 (AveragePoo (None, None, None, 2 0           concatenate_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_115 (BatchN (None, None, None, 4 192         conv2d_115[0][0]
# __________________________________________________________________________________________________
# batch_normalization_118 (BatchN (None, None, None, 9 384         conv2d_118[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_13 (AveragePo (None, None, None, 2 0           concatenate_17[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, None, None, 6 16448       concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, None, None, 6 76864       batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, None, None, 9 83040       batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, None, None, 3 8224        average_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_114 (Conv2D)             (None, None, None, 6 16448       concatenate_17[0][0]
# __________________________________________________________________________________________________
# conv2d_116 (Conv2D)             (None, None, None, 6 76864       batch_normalization_115[0][0]
# __________________________________________________________________________________________________
# conv2d_119 (Conv2D)             (None, None, None, 9 83040       batch_normalization_118[0][0]
# __________________________________________________________________________________________________
# conv2d_120 (Conv2D)             (None, None, None, 3 8224        average_pooling2d_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, None, None, 6 256         conv2d_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, None, None, 6 256         conv2d_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, None, None, 9 384         conv2d_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, None, None, 3 128         conv2d_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_114 (BatchN (None, None, None, 6 256         conv2d_114[0][0]
# __________________________________________________________________________________________________
# batch_normalization_116 (BatchN (None, None, None, 6 256         conv2d_116[0][0]
# __________________________________________________________________________________________________
# batch_normalization_119 (BatchN (None, None, None, 9 384         conv2d_119[0][0]
# __________________________________________________________________________________________________
# batch_normalization_120 (BatchN (None, None, None, 3 128         conv2d_120[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, None, None, 2 0           batch_normalization_20[0][0]
#                                                                  batch_normalization_22[0][0]
#                                                                  batch_normalization_25[0][0]
#                                                                  batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# concatenate_18 (Concatenate)    (None, None, None, 2 0           batch_normalization_114[0][0]
#                                                                  batch_normalization_116[0][0]
#                                                                  batch_normalization_119[0][0]
#                                                                  batch_normalization_120[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, None, None, 6 16448       concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_122 (Conv2D)             (None, None, None, 6 16448       concatenate_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, None, None, 6 256         conv2d_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_122 (BatchN (None, None, None, 6 256         conv2d_122[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, None, None, 9 55392       batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# conv2d_123 (Conv2D)             (None, None, None, 9 55392       batch_normalization_122[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, None, None, 9 384         conv2d_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_123 (BatchN (None, None, None, 9 384         conv2d_123[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, None, None, 3 885120      concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, None, None, 9 83040       batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# conv2d_121 (Conv2D)             (None, None, None, 3 885120      concatenate_18[0][0]
# __________________________________________________________________________________________________
# conv2d_124 (Conv2D)             (None, None, None, 9 83040       batch_normalization_123[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, None, None, 3 1536        conv2d_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, None, None, 9 384         conv2d_30[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, None, None, 2 0           concatenate_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_121 (BatchN (None, None, None, 3 1536        conv2d_121[0][0]
# __________________________________________________________________________________________________
# batch_normalization_124 (BatchN (None, None, None, 9 384         conv2d_124[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (None, None, None, 2 0           concatenate_18[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, None, None, 7 0           batch_normalization_27[0][0]
#                                                                  batch_normalization_30[0][0]
#                                                                  max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# concatenate_19 (Concatenate)    (None, None, None, 7 0           batch_normalization_121[0][0]
#                                                                  batch_normalization_124[0][0]
#                                                                  max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, None, None, 1 94336       concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv2d_129 (Conv2D)             (None, None, None, 1 94336       concatenate_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, None, None, 1 512         conv2d_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_129 (BatchN (None, None, None, 1 512         conv2d_129[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, None, None, 1 114816      batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# conv2d_130 (Conv2D)             (None, None, None, 1 114816      batch_normalization_129[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, None, None, 1 512         conv2d_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_130 (BatchN (None, None, None, 1 512         conv2d_130[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, None, None, 1 94336       concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, None, None, 1 114816      batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# conv2d_126 (Conv2D)             (None, None, None, 1 94336       concatenate_19[0][0]
# __________________________________________________________________________________________________
# conv2d_131 (Conv2D)             (None, None, None, 1 114816      batch_normalization_130[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, None, None, 1 512         conv2d_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, None, None, 1 512         conv2d_37[0][0]
# __________________________________________________________________________________________________
# batch_normalization_126 (BatchN (None, None, None, 1 512         conv2d_126[0][0]
# __________________________________________________________________________________________________
# batch_normalization_131 (BatchN (None, None, None, 1 512         conv2d_131[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, None, None, 1 114816      batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, None, None, 1 114816      batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# conv2d_127 (Conv2D)             (None, None, None, 1 114816      batch_normalization_126[0][0]
# __________________________________________________________________________________________________
# conv2d_132 (Conv2D)             (None, None, None, 1 114816      batch_normalization_131[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, None, None, 1 512         conv2d_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, None, None, 1 512         conv2d_38[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_4 (AveragePoo (None, None, None, 7 0           concatenate_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_127 (BatchN (None, None, None, 1 512         conv2d_127[0][0]
# __________________________________________________________________________________________________
# batch_normalization_132 (BatchN (None, None, None, 1 512         conv2d_132[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_14 (AveragePo (None, None, None, 7 0           concatenate_19[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, None, None, 1 141504      concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, None, None, 1 172224      batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, None, None, 1 172224      batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, None, None, 1 141504      average_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_125 (Conv2D)             (None, None, None, 1 141504      concatenate_19[0][0]
# __________________________________________________________________________________________________
# conv2d_128 (Conv2D)             (None, None, None, 1 172224      batch_normalization_127[0][0]
# __________________________________________________________________________________________________
# conv2d_133 (Conv2D)             (None, None, None, 1 172224      batch_normalization_132[0][0]
# __________________________________________________________________________________________________
# conv2d_134 (Conv2D)             (None, None, None, 1 141504      average_pooling2d_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, None, None, 1 768         conv2d_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, None, None, 1 768         conv2d_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, None, None, 1 768         conv2d_39[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, None, None, 1 768         conv2d_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_125 (BatchN (None, None, None, 1 768         conv2d_125[0][0]
# __________________________________________________________________________________________________
# batch_normalization_128 (BatchN (None, None, None, 1 768         conv2d_128[0][0]
# __________________________________________________________________________________________________
# batch_normalization_133 (BatchN (None, None, None, 1 768         conv2d_133[0][0]
# __________________________________________________________________________________________________
# batch_normalization_134 (BatchN (None, None, None, 1 768         conv2d_134[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, None, None, 7 0           batch_normalization_31[0][0]
#                                                                  batch_normalization_34[0][0]
#                                                                  batch_normalization_39[0][0]
#                                                                  batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# concatenate_20 (Concatenate)    (None, None, None, 7 0           batch_normalization_125[0][0]
#                                                                  batch_normalization_128[0][0]
#                                                                  batch_normalization_133[0][0]
#                                                                  batch_normalization_134[0][0]
# ...
#                                                                  concatenate_25[0][0]
#                                                                  concatenate_26[0][0]
#                                                                  batch_normalization_179[0][0]
# __________________________________________________________________________________________________
# batch_normalization_191 (BatchN (None, 14, 14, 512)  2048        drop_connect_5[0][0]
# __________________________________________________________________________________________________
# conv2d_90 (Conv2D)              (None, None, None, 4 917952      concatenate_12[0][0]
# __________________________________________________________________________________________________
# conv2d_184 (Conv2D)             (None, None, None, 4 917952      concatenate_27[0][0]
# __________________________________________________________________________________________________
# tmp_conv4 (Conv2D)              (None, 14, 14, 512)  2359808     batch_normalization_191[0][0]
# __________________________________________________________________________________________________
# batch_normalization_90 (BatchNo (None, None, None, 4 1792        conv2d_90[0][0]
# __________________________________________________________________________________________________
# batch_normalization_184 (BatchN (None, None, None, 4 1792        conv2d_184[0][0]
# __________________________________________________________________________________________________
# drop_connect_6 (DropConnect)    (None, 14, 14, 512)  262656      tmp_conv4[0][0]
# __________________________________________________________________________________________________
# conv2d_87 (Conv2D)              (None, None, None, 3 786816      concatenate_12[0][0]
# __________________________________________________________________________________________________
# conv2d_91 (Conv2D)              (None, None, None, 3 1548672     batch_normalization_90[0][0]
# __________________________________________________________________________________________________
# conv2d_181 (Conv2D)             (None, None, None, 3 786816      concatenate_27[0][0]
# __________________________________________________________________________________________________
# conv2d_185 (Conv2D)             (None, None, None, 3 1548672     batch_normalization_184[0][0]
# __________________________________________________________________________________________________
# batch_normalization_192 (BatchN (None, 14, 14, 512)  2048        drop_connect_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_87 (BatchNo (None, None, None, 3 1536        conv2d_87[0][0]
# __________________________________________________________________________________________________
# batch_normalization_91 (BatchNo (None, None, None, 3 1536        conv2d_91[0][0]
# __________________________________________________________________________________________________
# batch_normalization_181 (BatchN (None, None, None, 3 1536        conv2d_181[0][0]
# __________________________________________________________________________________________________
# batch_normalization_185 (BatchN (None, None, None, 3 1536        conv2d_185[0][0]
# __________________________________________________________________________________________________
# tmp_conv5 (Conv2D)              (None, 14, 14, 512)  2359808     batch_normalization_192[0][0]
# __________________________________________________________________________________________________
# conv2d_88 (Conv2D)              (None, None, None, 3 442752      batch_normalization_87[0][0]
# __________________________________________________________________________________________________
# conv2d_89 (Conv2D)              (None, None, None, 3 442752      batch_normalization_87[0][0]
# __________________________________________________________________________________________________
# conv2d_92 (Conv2D)              (None, None, None, 3 442752      batch_normalization_91[0][0]
# __________________________________________________________________________________________________
# conv2d_93 (Conv2D)              (None, None, None, 3 442752      batch_normalization_91[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_10 (AveragePo (None, None, None, 2 0           concatenate_12[0][0]
# __________________________________________________________________________________________________
# conv2d_182 (Conv2D)             (None, None, None, 3 442752      batch_normalization_181[0][0]
# __________________________________________________________________________________________________
# conv2d_183 (Conv2D)             (None, None, None, 3 442752      batch_normalization_181[0][0]
# __________________________________________________________________________________________________
# conv2d_186 (Conv2D)             (None, None, None, 3 442752      batch_normalization_185[0][0]
# __________________________________________________________________________________________________
# conv2d_187 (Conv2D)             (None, None, None, 3 442752      batch_normalization_185[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_20 (AveragePo (None, None, None, 2 0           concatenate_27[0][0]
# __________________________________________________________________________________________________
# drop_connect_7 (DropConnect)    (None, 14, 14, 512)  262656      tmp_conv5[0][0]
# __________________________________________________________________________________________________
# conv2d_86 (Conv2D)              (None, None, None, 3 655680      concatenate_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_88 (BatchNo (None, None, None, 3 1536        conv2d_88[0][0]
# __________________________________________________________________________________________________
# batch_normalization_89 (BatchNo (None, None, None, 3 1536        conv2d_89[0][0]
# __________________________________________________________________________________________________
# batch_normalization_92 (BatchNo (None, None, None, 3 1536        conv2d_92[0][0]
# __________________________________________________________________________________________________
# batch_normalization_93 (BatchNo (None, None, None, 3 1536        conv2d_93[0][0]
# __________________________________________________________________________________________________
# conv2d_94 (Conv2D)              (None, None, None, 1 393408      average_pooling2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_180 (Conv2D)             (None, None, None, 3 655680      concatenate_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_182 (BatchN (None, None, None, 3 1536        conv2d_182[0][0]
# __________________________________________________________________________________________________
# batch_normalization_183 (BatchN (None, None, None, 3 1536        conv2d_183[0][0]
# __________________________________________________________________________________________________
# batch_normalization_186 (BatchN (None, None, None, 3 1536        conv2d_186[0][0]
# __________________________________________________________________________________________________
# batch_normalization_187 (BatchN (None, None, None, 3 1536        conv2d_187[0][0]
# __________________________________________________________________________________________________
# conv2d_188 (Conv2D)             (None, None, None, 1 393408      average_pooling2d_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_193 (BatchN (None, 14, 14, 512)  2048        drop_connect_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_86 (BatchNo (None, None, None, 3 1280        conv2d_86[0][0]
# __________________________________________________________________________________________________
# concatenate_13 (Concatenate)    (None, None, None, 7 0           batch_normalization_88[0][0]
#                                                                  batch_normalization_89[0][0]
# __________________________________________________________________________________________________
# concatenate_14 (Concatenate)    (None, None, None, 7 0           batch_normalization_92[0][0]
#                                                                  batch_normalization_93[0][0]
# __________________________________________________________________________________________________
# batch_normalization_94 (BatchNo (None, None, None, 1 768         conv2d_94[0][0]
# __________________________________________________________________________________________________
# batch_normalization_180 (BatchN (None, None, None, 3 1280        conv2d_180[0][0]
# __________________________________________________________________________________________________
# concatenate_28 (Concatenate)    (None, None, None, 7 0           batch_normalization_182[0][0]
#                                                                  batch_normalization_183[0][0]
# __________________________________________________________________________________________________
# concatenate_29 (Concatenate)    (None, None, None, 7 0           batch_normalization_186[0][0]
#                                                                  batch_normalization_187[0][0]
# __________________________________________________________________________________________________
# batch_normalization_188 (BatchN (None, None, None, 1 768         conv2d_188[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_9 (MaxPooling2D)  (None, 7, 7, 512)    0           batch_normalization_193[0][0]
# __________________________________________________________________________________________________
# concatenate_15 (Concatenate)    (None, None, None, 2 0           batch_normalization_86[0][0]
#                                                                  concatenate_13[0][0]
#                                                                  concatenate_14[0][0]
#                                                                  batch_normalization_94[0][0]
# __________________________________________________________________________________________________
# concatenate_30 (Concatenate)    (None, None, None, 2 0           batch_normalization_180[0][0]
#                                                                  concatenate_28[0][0]
#                                                                  concatenate_29[0][0]
#                                                                  batch_normalization_188[0][0]
# __________________________________________________________________________________________________
# conv2d_189 (Conv2D)             (None, 5, 5, 2048)   9439232     max_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_1 (Glo (None, 2048)         0           concatenate_15[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_2 (Glo (None, 2048)         0           concatenate_30[0][0]
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 25, 2048)     0           conv2d_189[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 256)          524544      global_average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 256)          524544      global_average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# lstm_1 (LSTM)                   (None, 256)          2360320     reshape_1[0][0]
# __________________________________________________________________________________________________
# drop_connect_1 (DropConnect)    (None, 256)          65792       dense_1[0][0]
# __________________________________________________________________________________________________
# drop_connect_2 (DropConnect)    (None, 256)          65792       dense_3[0][0]
# __________________________________________________________________________________________________
# drop_connect_8 (DropConnect)    (None, 256)          65792       lstm_1[0][0]
# __________________________________________________________________________________________________
# gadogado_layer (Average)        (None, 256)          0           drop_connect_1[0][0]
#                                                                  drop_connect_2[0][0]
#                                                                  drop_connect_8[0][0]
# __________________________________________________________________________________________________
# dense_11 (Dense)                (None, 1024)         263168      gadogado_layer[0][0]
# __________________________________________________________________________________________________
# drop_connect_9 (DropConnect)    (None, 1024)         1049600     dense_11[0][0]
# __________________________________________________________________________________________________
# dense_13 (Dense)                (None, 4)            4100        drop_connect_9[0][0]
# ==================================================================================================
# Total params: 64,986,084
# Trainable params: 21,758,372
# Non-trainable params: 43,227,712
# __________________________________________________________________________________________________
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\tfgpu\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/30
# Found 7100 images belonging to 4 classes.
# Found 7100 images belonging to 4 classes.
# Found 23750 images belonging to 4 classes.
# Found 7100 images belonging to 4 classes.
# Found 23750 images belonging to 4 classes.
# Found 23750 images belonging to 4 classes.
# 950/950 [==============================] - 1063s 1s/step - loss: 1.7289 - acc: 0.3371 - val_loss: 1.3882 - val_acc: 0.3183
#
# Epoch 00001: val_acc improved from -inf to 0.31831, saving model to incept(global)_incept(local)_incept(of)_avg.001-1.39-0.32.hdf5
# Epoch 2/30
# 950/950 [==============================] - 1036s 1s/step - loss: 1.5852 - acc: 0.2832 - val_loss: 1.3817 - val_acc: 0.3290
#
# Epoch 00002: val_acc improved from 0.31831 to 0.32901, saving model to incept(global)_incept(local)_incept(of)_avg.002-1.38-0.33.hdf5
# Epoch 3/30
# 557/950 [================>.............] - ETA: 6:15 - loss: 1.3458 - acc: 0.3698

# %% [markdown]
# # Testing Purpose

# %%
from keras.models import load_model
model = load_model('utils/checkpoints/lstm/incept(global)_incept(local)_avg.011-2.28-0.34.hdf5')

# %%
"""
Classify test images set through our CNN.
Use keras 2+ and tensorflow 1+
It takes a long time for hours.
"""
import numpy as np
import operator
import random
import glob
from keras.models import load_model
from keras.preprocessing.image import ImageDataGenerator


# CNN model evaluate

test_data_gen = ImageDataGenerator(rescale=1. / 255)
batch_size = 25
test_path = 'data/test'  #path to your validation / test videos
test_generator = test_data_gen.flow_from_directory(test_path, target_size=(224, 224),
                                                   batch_size=batch_size, classes=['angry','happy','sad', 'submissive'],
                                                   class_mode='categorical',shuffle = False)

# %%
test_generator=generate_generator_multiple(test_data_gen,
                                          dir1='data/test',
                                          dir2='object_data/test',
                                          batch_size=batch_size,
                                          img_height=224,
                                          img_width=224)

# %%
test_data_num = 14950          
#test_generator.reset() #to avoid having bugs in generator.
# if you dont invoke .reset(), it will starts to mix the order of the array from predicted generator

predicted_array = model.predict_generator(test_generator, steps = test_data_num/batch_size)
len(predicted_array) #check if generated data is the same as test_data_num

# %% [markdown]
# ### Documentation section

# %%
frame = [] #check all frame names for each validation / test videos
filenames = [] #check all filenames for each validation / test videos
gt = [] #ground truth storage for each validation / test videos
length = [] #how many frames belongs to which test / validation videos
final_predicted_array = [] #final predicted results for all videos

catfiles = os.listdir(test_path)
for i in range(len(catfiles)):
    subvideos = os.listdir(os.path.join(test_path,catfiles[i]))
    filenames.extend(subvideos)
    for j in range(len(subvideos)):
        contentvideos = os.listdir(os.path.join(test_path,catfiles[i],subvideos[j]))
        frame.append(contentvideos)
        length.append(len(contentvideos))
        gt.append(i)
cum_length = np.cumsum(length)
test2 = predicted_array[:cum_length[0]]
final_predicted_array.append(test2)
for i in range(len(cum_length)-1):
    test2 = predicted_array[cum_length[i]:cum_length[i+1]]
    final_predicted_array.append(test2)
votepred = []
meanpred = []

for i in range(len(final_predicted_array)):
    votectg = np.bincount(np.argmax(final_predicted_array[i], axis=1))
    votepred.append(np.argmax(votectg))
    meanctg = np.argmax(np.mean(final_predicted_array[i], axis=0))
    meanpred.append(meanctg)

vote = 0
mean = 0
for i in range(len(gt)):
    if(gt[i] == votepred[i]):
        vote += 1
    if(gt[i] == meanpred[i]):
        mean += 1
        
vote_acc = vote/len(gt)
mean_acc = mean/len(gt)

print("Voting accuracy : ", vote_acc)
print("Mean accuracy : ", mean_acc)
